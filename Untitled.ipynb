# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
df = pd.read_csv("heart.csv")

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
sns.histplot(data=df, x="chol", hue="age", multiple="stack")
# Out:
# <AxesSubplot:xlabel='chol', ylabel='Count'>

# %%
sns.set(font_scale=2)
df.hist(figsize=(30,30))
plt.show()

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x='slope', data=df)
# Out:
# <AxesSubplot:xlabel='slope', ylabel='count'>

# %%
sns.countplot(x='sex', hue='target', data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.countplot(x='age', hue='target', data=df)
# Out:
# <AxesSubplot:xlabel='age', ylabel='count'>

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
list(df.columns)
# Out:
# ['age',
#  'sex',
#  'cp',
#  'trestbps',
#  'chol',
#  'fbs',
#  'restecg',
#  'thalach',
#  'exang',
#  'oldpeak',
#  'slope',
#  'ca',
#  'thal',
#  'target']

# %%
categorical_values = list(df.columns)
categorical_values.remove('target')
categorical_values
# Out:
# ['age',
#  'sex',
#  'cp',
#  'trestbps',
#  'chol',
#  'fbs',
#  'restecg',
#  'thalach',
#  'exang',
#  'oldpeak',
#  'slope',
#  'ca',
#  'thal']

# %%
plt.figure(figsize=(30,30))
for i, col in enumerate(categorical_values, 1):
    plt.subplot(4,4,i)
    sns.barplot(x=f"{col}",y='target', data=df)
    plt.ylabel("Possibility of having heart diseases")
    plt.xlabel(f"{col}")

# %%
sns.scatterplot(data = df, x = "age", y = "sex", hue="chol")

plt.show()

# %%
x = df.drop("R", axis=1)
y = df['x']
print(y)
testing_size = 0.2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4528/944969084.py in <module>
# ----> 1 x = df.drop("R", axis=1)
#       2 y = df['x']
#       3 print(y)
#       4 testing_size = 0.2
#
# ~\anaconda3\ana\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\ana\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...
